# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df_temp=pd.read_csv(".\Data\TVS.csv",low_memory="false")
df_temp
# Out:
#             V1  V2  V3    V4   V5      V6       V7    V8      V9  V10  ...  \
# 0            1   0   0  24.0  0.0  2432.0  46500.0  24.0  1385.0   SC  ...
# 1            2   0   1  24.0  1.0  1495.0  28168.0  24.0  2496.0   MO  ...
# 2            3   0   0  26.0  0.0  1707.0  38900.0  30.0  1346.0   SC  ...
# 3            4   0   0  24.0  0.0  2128.0  42900.0  24.0  1375.0   SC  ...
# 4            5   0   0  27.0  0.0  1824.0  40900.0  30.0  4140.0   MC  ...
# ...        ...  ..  ..   ...  ...     ...      ...   ...     ...  ...  ...
# 119523  119524   0   1   NaN  NaN     NaN      NaN   NaN     NaN  NaN  ...
# 119524  119525   0   0   NaN  NaN     NaN      NaN   NaN     NaN  NaN  ...
# 119525  119526   0   0   NaN  NaN     NaN      NaN   NaN     NaN  NaN  ...
# 119526  119527   0   1   NaN  NaN     NaN      NaN   NaN     NaN  NaN  ...
# 119527  119528   0   0   NaN  NaN     NaN      NaN   NaN     NaN  NaN  ...
#
#         V23       V24      V25   V26   V27 V28  V29  V30     V31  V32
# 0       NaN       NaN  46500.0   NaN   NaN   0    0    0  TIER 1    0
# 1       NaN       NaN  28168.0   NaN   NaN   0    0    0  TIER 1    0
# 2       NaN  105000.0  38900.0  34.0  31.0  31   31   16  TIER 1    0
# 3       NaN       NaN  42900.0   NaN   NaN   0    0    0  TIER 1    0
# 4       NaN       NaN  40900.0   NaN   NaN   0    0    0  TIER 1    0
# ...     ...       ...      ...   ...   ...  ..  ...  ...     ...  ...
# 119523  NaN       NaN      NaN   NaN   NaN   0    0    0  TIER 3    0
# 119524  NaN       NaN  33000.0   NaN   NaN   3    1    0  TIER 3    1
# 119525  NaN       NaN      NaN   NaN   NaN   0    0    0  TIER 3    0
# 119526  NaN   31990.0  43600.0   NaN  13.0   0    0    0  TIER 1    0
# 119527  NaN       NaN  49900.0   NaN  30.0   4    3    0  TIER 2    0
#
# [119528 rows x 32 columns]

# %%
import sklearn.feature_selection as fs
x=df_temp.iloc[:,0:31]
y=pd.DataFrame(df_temp["V32"])
x,y
# Out:
# (            V1  V2  V3    V4   V5      V6       V7    V8      V9  V10  ...  \
#  0            1   0   0  24.0  0.0  2432.0  46500.0  24.0  1385.0   SC  ...
#  1            2   0   1  24.0  1.0  1495.0  28168.0  24.0  2496.0   MO  ...
#  2            3   0   0  26.0  0.0  1707.0  38900.0  30.0  1346.0   SC  ...
#  3            4   0   0  24.0  0.0  2128.0  42900.0  24.0  1375.0   SC  ...
#  4            5   0   0  27.0  0.0  1824.0  40900.0  30.0  4140.0   MC  ...
#  ...        ...  ..  ..   ...  ...     ...      ...   ...     ...  ...  ...
#  119523  119524   0   1   NaN  NaN     NaN      NaN   NaN     NaN  NaN  ...
#  119524  119525   0   0   NaN  NaN     NaN      NaN   NaN     NaN  NaN  ...
#  119525  119526   0   0   NaN  NaN     NaN      NaN   NaN     NaN  NaN  ...
#  119526  119527   0   1   NaN  NaN     NaN      NaN   NaN     NaN  NaN  ...
#  119527  119528   0   0   NaN  NaN     NaN      NaN   NaN     NaN  NaN  ...
#
#          V22  V23       V24      V25   V26   V27  V28  V29  V30     V31
#  0         0  NaN       NaN  46500.0   NaN   NaN    0    0    0  TIER 1
#  1         0  NaN       NaN  28168.0   NaN   NaN    0    0    0  TIER 1
#  2         0  NaN  105000.0  38900.0  34.0  31.0   31   31   16  TIER 1
#  3         0  NaN       NaN  42900.0   NaN   NaN    0    0    0  TIER 1
#  4         0  NaN       NaN  40900.0   NaN   NaN    0    0    0  TIER 1
#  ...     ...  ...       ...      ...   ...   ...  ...  ...  ...     ...
#  119523    0  NaN       NaN      NaN   NaN   NaN    0    0    0  TIER 3
#  119524    0  NaN       NaN  33000.0   NaN   NaN    3    1    0  TIER 3
#  119525    0  NaN       NaN      NaN   NaN   NaN    0    0    0  TIER 3
#  119526    0  NaN   31990.0  43600.0   NaN  13.0    0    0    0  TIER 1
#  119527    0  NaN       NaN  49900.0   NaN  30.0    4    3    0  TIER 2
#
#  [119528 rows x 31 columns],
#          V32
#  0         0
#  1         0
#  2         0
#  3         0
#  4         0
#  ...     ...
#  119523    0
#  119524    1
#  119525    0
#  119526    0
#  119527    0
#
#  [119528 rows x 1 columns])

# %%
x=x.drop(["V1"],axis=1)
x
# Out:
#         V2  V3    V4   V5      V6       V7    V8      V9  V10  V11  ...  V22  \
# 0        0   0  24.0  0.0  2432.0  46500.0  24.0  1385.0   SC  0.0  ...    0
# 1        0   1  24.0  1.0  1495.0  28168.0  24.0  2496.0   MO  0.0  ...    0
# 2        0   0  26.0  0.0  1707.0  38900.0  30.0  1346.0   SC  0.0  ...    0
# 3        0   0  24.0  0.0  2128.0  42900.0  24.0  1375.0   SC  2.0  ...    0
# 4        0   0  27.0  0.0  1824.0  40900.0  30.0  4140.0   MC  0.0  ...    0
# ...     ..  ..   ...  ...     ...      ...   ...     ...  ...  ...  ...  ...
# 119523   0   1   NaN  NaN     NaN      NaN   NaN     NaN  NaN  NaN  ...    0
# 119524   0   0   NaN  NaN     NaN      NaN   NaN     NaN  NaN  NaN  ...    0
# 119525   0   0   NaN  NaN     NaN      NaN   NaN     NaN  NaN  NaN  ...    0
# 119526   0   1   NaN  NaN     NaN      NaN   NaN     NaN  NaN  NaN  ...    0
# 119527   0   0   NaN  NaN     NaN      NaN   NaN     NaN  NaN  NaN  ...    0
#
#        V23       V24      V25   V26   V27  V28  V29  V30     V31
# 0      NaN       NaN  46500.0   NaN   NaN    0    0    0  TIER 1
# 1      NaN       NaN  28168.0   NaN   NaN    0    0    0  TIER 1
# 2      NaN  105000.0  38900.0  34.0  31.0   31   31   16  TIER 1
# 3      NaN       NaN  42900.0   NaN   NaN    0    0    0  TIER 1
# 4      NaN       NaN  40900.0   NaN   NaN    0    0    0  TIER 1
# ...     ..       ...      ...   ...   ...  ...  ...  ...     ...
# 119523 NaN       NaN      NaN   NaN   NaN    0    0    0  TIER 3
# 119524 NaN       NaN  33000.0   NaN   NaN    3    1    0  TIER 3
# 119525 NaN       NaN      NaN   NaN   NaN    0    0    0  TIER 3
# 119526 NaN   31990.0  43600.0   NaN  13.0    0    0    0  TIER 1
# 119527 NaN       NaN  49900.0   NaN  30.0    4    3    0  TIER 2
#
# [119528 rows x 30 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df_temp.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
x.describe()
# Out:
#                   V2             V3            V4            V5            V6  \
# count  119528.000000  119528.000000  85048.000000  85048.000000  85048.000000
# mean        0.028378       0.473061     17.217148      0.690857   2325.701298
# std         0.166052       0.859042      5.203209      1.091658    575.614365
# min         0.000000       0.000000      2.000000      0.000000    681.000000
# 25%         0.000000       0.000000     14.000000      0.000000   1895.000000
# 50%         0.000000       0.000000     17.000000      0.000000   2320.000000
# 75%         0.000000       1.000000     21.000000      1.000000   2689.000000
# max         1.000000      12.000000     36.000000     29.000000   7840.000000
#
#                  V7            V8            V9           V11           V12  \
# count  85048.000000  85048.000000  85048.000000  85048.000000  85048.000000
# mean   39338.081648     21.060048   3512.692233      0.643930     11.703803
# std    11016.619745      5.698900   3754.675342      0.969123      3.980542
# min    10000.000000      6.000000   1001.000000      0.000000      0.000000
# 25%    30000.000000     18.000000   1368.000000      0.000000      9.500000
# 50%    39700.000000     24.000000   2307.000000      0.000000     12.600000
# 75%    48000.000000     24.000000   3911.000000      1.000000     14.090000
# max    96000.000000     36.000000  21106.000000      6.000000     20.650000
#
#        ...           V21       V22           V23           V24            V25  \
# count  ...  3.662600e+04  119528.0  1.928100e+04  1.902800e+04  104467.000000
# mean   ...  2.742192e+05       0.0  4.302522e+05  1.766494e+05   41415.210047
# std    ...  7.916241e+05       0.0  8.228143e+05  4.075618e+05   13044.008078
# min    ...  1.000000e+00       0.0  9.900000e+01  1.000000e+00   10000.000000
# 25%    ...  4.190700e+04       0.0  4.490000e+04  3.394050e+04   31000.000000
# 50%    ...  9.500000e+04       0.0  1.100000e+05  8.800000e+04   42250.000000
# 75%    ...  3.000000e+05       0.0  4.920000e+05  2.000048e+05   49300.000000
# max    ...  1.000000e+08       0.0  2.022777e+07  3.000000e+07  700000.000000
#
#                 V26           V27            V28            V29            V30
# count  13431.000000  20433.000000  119528.000000  119528.000000  119528.000000
# mean      46.980940     48.208976       1.076877       0.823991       0.344898
# std       42.716225     41.713826       3.737882       3.172612       1.478180
# min        4.000000      4.000000       0.000000       0.000000       0.000000
# 25%       20.000000     23.000000       0.000000       0.000000       0.000000
# 50%       31.000000     35.000000       0.000000       0.000000       0.000000
# 75%       52.000000     55.000000       0.000000       0.000000       0.000000
# max      252.000000    268.000000     314.000000     243.000000      96.000000
#
# [8 rows x 24 columns]

# %%
x["V10"].mode()
# Out:
# 0    SC
# Name: V10, dtype: object

# %%
x["V14"]=x["V14"].fillna("Z")

# %%
x["V10"]=x["V10"].fillna("SC")

# %%
list_V10=x["V10"].unique()
sorted(list_V10)
# Out:
# ['MC', 'MO', 'RETOP', 'SC', 'TL']

# %%
list_V14=x["V14"].unique()
sorted(list_V14)
# Out:
# ['HOUSEWIFE', 'PENS', 'SAL', 'SELF', 'STUDENT', 'Z']

# %%
x["V15"]=x["V15"].fillna("NO")

# %%
list_V15=x["V15"].unique()
sorted(list_V15)
# Out:
# ['NO', 'OWENED BY OFFICE', 'OWNED', 'RENT']

# %%
x=x.drop(['V16'],axis=1)

# %%
x["V17"]=x["V17"].fillna(x["V17"].mean())

# %%
x["V21"]=x["V21"].fillna(0)

# %%
x=x.drop(["V21","V22","V23","V24","V26","V27"],axis=1)

# %%
x["V25"]=x["V25"].fillna(x["V25"].mean())

# %%
sns.heatmap(x.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
  
x["V31"]=label_encoder.fit_transform(x["V31"]) #Tier1=0,Tier2=1,Tier3=2
x["V10"]=label_encoder.fit_transform(x["V10"]) #Motorcycle-0,Moped-1,Retop-2,Scooter-3,Tl-4
x["V13"]=label_encoder.fit_transform(x["V13"]) #Female-0,Male-1
x["V14"]=label_encoder.fit_transform(x["V14"]) #Houswife-0,Pension-1,Salaried-2,Self-3,Student-4,Unemployed-5
x["V15"]=label_encoder.fit_transform(x["V15"]) #Others-0,Office-Owned-1,Owned-2,Rent-3

# %%
x["V4"]=x["V4"].fillna(x["V4"].mean())
x["V5"]=x["V5"].fillna(x["V5"].mean())
x["V6"]=x["V6"].fillna(x["V6"].mean())
x["V7"]=x["V7"].fillna(x["V7"].mean())
x["V8"]=x["V8"].fillna(x["V8"].mean())
x["V9"]=x["V9"].fillna(x["V9"].mean())
x["V11"]=x["V11"].fillna(x["V11"].mean())
x["V12"]=x["V12"].fillna(x["V12"].mean())
x["V13"]=x["V13"].fillna(x["V13"].mean())

# %%
dfvis= x.join(y)
dfvis
# Out:
#         V2  V3         V4        V5           V6            V7         V8  \
# 0        0   0  24.000000  0.000000  2432.000000  46500.000000  24.000000
# 1        0   1  24.000000  1.000000  1495.000000  28168.000000  24.000000
# 2        0   0  26.000000  0.000000  1707.000000  38900.000000  30.000000
# 3        0   0  24.000000  0.000000  2128.000000  42900.000000  24.000000
# 4        0   0  27.000000  0.000000  1824.000000  40900.000000  30.000000
# ...     ..  ..        ...       ...          ...           ...        ...
# 119523   0   1  17.217148  0.690857  2325.701298  39338.081648  21.060048
# 119524   0   0  17.217148  0.690857  2325.701298  39338.081648  21.060048
# 119525   0   0  17.217148  0.690857  2325.701298  39338.081648  21.060048
# 119526   0   1  17.217148  0.690857  2325.701298  39338.081648  21.060048
# 119527   0   0  17.217148  0.690857  2325.701298  39338.081648  21.060048
#
#                  V9  V10      V11  ...        V17  V18  V19  V20  \
# 0       1385.000000    3  0.00000  ...  40.000000    1    1    0
# 1       2496.000000    1  0.00000  ...  47.000000    1    1    0
# 2       1346.000000    3  0.00000  ...  31.000000    9    6    3
# 3       1375.000000    3  2.00000  ...  24.000000    1    1    0
# 4       4140.000000    0  0.00000  ...  30.000000    1    1    0
# ...             ...  ...      ...  ...        ...  ...  ...  ...
# 119523  3512.692233    3  0.64393  ...  37.003645    0    0    0
# 119524  3512.692233    3  0.64393  ...  37.003645    1    1    0
# 119525  3512.692233    3  0.64393  ...  37.003645    0    0    0
# 119526  3512.692233    3  0.64393  ...  37.003645    4    1    2
# 119527  3512.692233    3  0.64393  ...  37.003645    5    4    1
#
#                  V25  V28  V29  V30  V31  V32
# 0       46500.000000    0    0    0    0    0
# 1       28168.000000    0    0    0    0    0
# 2       38900.000000   31   31   16    0    0
# 3       42900.000000    0    0    0    0    0
# 4       40900.000000    0    0    0    0    0
# ...              ...  ...  ...  ...  ...  ...
# 119523  41415.210047    0    0    0    2    0
# 119524  33000.000000    3    1    0    2    1
# 119525  41415.210047    0    0    0    2    0
# 119526  43600.000000    0    0    0    0    0
# 119527  49900.000000    4    3    0    1    0
#
# [119528 rows x 24 columns]

# %%
sns.set (rc = {'figure.figsize':(20, 20)})
dataplot = sns.heatmap(dfvis.corr(), cmap="YlGnBu", annot=True)
dataplot
# Out:
# <Axes: >

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
uni = SelectKBest(score_func = f_classif, k = 6)
fit = uni.fit(x, y)
features=x.columns[fit.get_support(indices=True)].tolist()
features
# Out:
# ['V3', 'V5', 'V17', 'V28', 'V29', 'V30']

# %%
pip install lazypredict
# Out:
# Requirement already satisfied: lazypredict in c:\users\crash\appdata\roaming\python\python311\site-packages (0.2.12)
# Requirement already satisfied: click in c:\users\crash\appdata\roaming\python\python311\site-packages (from lazypredict) (8.1.3)
# Requirement already satisfied: scikit-learn in c:\users\crash\appdata\roaming\python\python311\site-packages (from lazypredict) (1.2.2)
# Requirement already satisfied: pandas in c:\users\crash\appdata\roaming\python\python311\site-packages (from lazypredict) (1.5.3)
# Requirement already satisfied: tqdm in c:\users\crash\appdata\roaming\python\python311\site-packages (from lazypredict) (4.64.1)
# Requirement already satisfied: joblib in c:\users\crash\appdata\roaming\python\python311\site-packages (from lazypredict) (1.2.0)
# Requirement already satisfied: lightgbm in c:\users\crash\appdata\roaming\python\python311\site-packages (from lazypredict) (3.3.5)
# Requirement already satisfied: xgboost in c:\users\crash\appdata\roaming\python\python311\site-packages (from lazypredict) (1.7.5)
# Requirement already satisfied: colorama in c:\users\crash\appdata\roaming\python\python311\site-packages (from click->lazypredict) (0.4.6)
# Requirement already satisfied: wheel in c:\users\crash\appdata\roaming\python\python311\site-packages (from lightgbm->lazypredict) (0.38.4)
# Requirement already satisfied: numpy in c:\users\crash\appdata\roaming\python\python311\site-packages (from lightgbm->lazypredict) (1.23.5)
# Requirement already satisfied: scipy in c:\users\crash\appdata\roaming\python\python311\site-packages (from lightgbm->lazypredict) (1.10.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\crash\appdata\roaming\python\python311\site-packages (from scikit-learn->lazypredict) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\crash\appdata\roaming\python\python311\site-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\crash\appdata\roaming\python\python311\site-packages (from pandas->lazypredict) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\crash\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.1->pandas->lazypredict) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from lazypredict.Supervised import LazyClassifier, LazyRegressor
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)
classifiers = LazyClassifier(ignore_warnings=True, custom_metric=None)
models,predictions = classifiers.fit(x_train, x_test, y_train, y_test)
models,predictions
